# %% [markdown]
# ### 1

# %% [markdown]
# Seaborn is a powerful Python data visualization library built on top of Matplotlib. It is specifically designed for creating aesthetically pleasing and informative statistical graphics. Seaborn provides a variety of high-level functions to create different types of plots. Here are five common plots you can create using Seaborn, along with their typical uses:
#
# 1. **Histograms (`sns.histplot`)**:Histograms are used to visualize the distribution of a single numerical variable. They display the frequency or density of data points in different bins or intervals.
#
# 2. **Scatter Plots (`sns.scatterplot`)**:Scatter plots are used to visualize the relationship between two numerical variables. They show individual data points as dots on a Cartesian plane, making it easy to identify patterns, trends, or correlations.
#
# 3. **Bar Plots (`sns.barplot`)**:Bar plots are used to compare the values of different categories or groups. They display rectangular bars where the length of each bar corresponds to a value, making it easy to compare magnitudes.
#
# 4. **Box Plots (`sns.boxplot`)**:Box plots, also known as box-and-whisker plots, are used to display the distribution and summary statistics of numerical data. They help identify outliers and visualize the spread and central tendency of the data.
#
# 5. **Heatmaps (`sns.heatmap`)**:Heatmaps are used to visualize the correlation or relationships between variables in a tabular dataset. They use color intensity to represent the strength and direction of relationships.

# %% [markdown]
# ### 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ds=sns.load_dataset('fmri')
sns.lineplot(x ="timepoint",y = "signal",hue="event", style="region",data=ds)

# %% [markdown]
# ### 3

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset('titanic')
sns.boxplot(x ='pclass', y = 'age',data=data)
plt.show()
sns.boxplot(x ='pclass', y = 'fare',data=data)
plt.show()

# %% [markdown]
# ### 4

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset('diamonds')
sns.histplot(x='price',hue='cut',data=data,bins=40)
plt.show()

# %% [markdown]
# ### 5

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset('iris')
sns.pairplot(data=data,hue='species')
plt.show()

# %% [markdown]
# ### 6

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "flights" dataset
flights_data = sns.load_dataset("flights")

# Pivot the dataset to create a matrix suitable for a heatmap
flights_pivot = flights_data.pivot_table(index='month', columns='year', values='passengers')

# Create a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(data=flights_pivot, cmap='coolwarm', annot=True, fmt="d", linewidths=.5)

# Add labels and a title
plt.xlabel("Year")
plt.ylabel("Month")
plt.title("Passenger Counts (Flights Dataset)")

# Show the plot
plt.show()
